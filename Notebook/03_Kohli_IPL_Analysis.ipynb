# %% [markdown]
# # 🏏 Kohli IPL Performance Analysis
#
# This notebook provides an in-depth analysis of Virat Kohli's performance in the **Indian Premier League (IPL)** over the years.
#
# We will explore:
# - Total runs per season
# - Batting average and strike rate
# - Number of 50s and 100s
# - Consistency and standout seasons

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set seaborn style for all plots
sns.set(style='whitegrid')

# %%
df_ipl = pd.read_csv('../Data/Virat_Kohli_YearWise_with_IPL.csv')
df_ipl.head()
# Out:
#   Format  Year  Matches  Innings  Runs  Average HighestScore  Fifties  \
# 0   Test  2011        3        5   202     22.4           63        2
# 1   Test  2016       12       20  1215     75.0          200        5
# 2   Test  2019       15       25  1408     56.3         254*        6
# 3   Test  2023        6       10   550     55.0          120        2
# 4    ODI  2011       34       34  1381     47.6          117        8
#
#    Centuries
# 0          0
# 1          3
# 2          5
# 3          1
# 4          4

# %%
df_ipl.columns
# Out:
# Index(['Format', 'Year', 'Matches', 'Innings', 'Runs', 'Average',
#        'HighestScore', 'Fifties', 'Centuries'],
#       dtype='object')

# %%
df_ipl.columns = df_ipl.columns.str.strip().str.replace(' ', '_').str.replace('(', '').str.replace(')', '')

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df_ipl, x='Year', y='Runs', palette='crest')
plt.title("Virat Kohli - Total IPL Runs Per Year")
plt.xlabel("Year")
plt.ylabel("Runs")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2812\1079569900.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_ipl, x='Year', y='Runs', palette='crest')

# %% [markdown]
# ## 📈 Kohli's IPL Batting Average Over the Years
# Let's explore how consistent Kohli has been in terms of his batting average throughout his IPL journey.

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_ipl, x='Year', y='Average', marker='o', color='green')
plt.title("Virat Kohli - IPL Batting Average Per Year")
plt.xlabel("Year")
plt.ylabel("Batting Average")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🧨 Fifties and Centuries Comparison (Year-wise)
# This chart compares the number of 50s and 100s Kohli scored in each IPL season.

# %%
plt.figure(figsize=(10, 6))
plt.plot(df_ipl['Year'], df_ipl['Fifties'], marker='o', label='Fifties', color='blue')
plt.plot(df_ipl['Year'], df_ipl['Centuries'], marker='o', label='Centuries', color='red')
plt.title('Virat Kohli - 50s vs 100s Per IPL Season')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🚀 Kohli's Total IPL Runs Per Season
# This chart highlights Kohli’s overall contribution to RCB each year by showing total runs scored per IPL season.

# %%
plt.figure(figsize=(10, 6))
sns.barplot(data=df_ipl, x='Year', y='Runs', palette='viridis')
plt.title("Virat Kohli - Total IPL Runs Per Season")
plt.xlabel("Year")
plt.ylabel("Runs")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_2812\874465697.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_ipl, x='Year', y='Runs', palette='viridis')

# %% [markdown]
# ## 💯 Kohli's Best Season in IPL - 2016
# Kohli had a legendary IPL 2016 season, scoring **973 runs** — the most ever in a single season! Let's highlight that.

# %%
best_season = df_ipl[df_ipl['Runs'] == df_ipl['Runs'].max()]
print(best_season)
# Out:
#   Format  Year  Matches  Innings  Runs  Average HighestScore  Fifties  \
# 5    ODI  2017       26       26  1460     76.8          131        7
#
#    Centuries
# 5          6

# %% [markdown]
# ## 🎯 Strike Rate Trend - Kohli's Attacking Style Over the Years
# This chart reveals how Kohli’s batting approach evolved by tracking his strike rate each season.

# %%
df_ipl.columns
# Out:
# Index(['Format', 'Year', 'Matches', 'Innings', 'Runs', 'Average',
#        'HighestScore', 'Fifties', 'Centuries'],
#       dtype='object')

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_ipl, x='Year', y='Matches', marker='o', label='Matches', color='blue')
sns.lineplot(data=df_ipl, x='Year', y='Innings', marker='o', label='Innings', color='orange')
plt.title("Virat Kohli - Matches vs Innings per IPL Year")
plt.xlabel("Year")
plt.ylabel("Count")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
#  1. Highest Score Trend Per Year

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_ipl, x='Year', y='HighestScore', marker='o', color='darkred')
plt.title("Virat Kohli - Highest Score Per IPL Season")
plt.xlabel("Year")
plt.ylabel("Highest Score")
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 2. Fifties vs Centuries Per Year

# %%
plt.figure(figsize=(10, 6))
plt.plot(df_ipl['Year'], df_ipl['Fifties'], marker='o', label='Fifties', color='skyblue')
plt.plot(df_ipl['Year'], df_ipl['Centuries'], marker='o', label='Centuries', color='orange')
plt.title('Virat Kohli - Fifties vs Centuries Per IPL Year')
plt.xlabel('Year')
plt.ylabel('Count')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %% [markdown]
# 3. Batting Average Trend Per Year

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_ipl, x='Year', y='Average', marker='o', color='seagreen')
plt.title("Virat Kohli - Batting Average Per IPL Season")
plt.xlabel("Year")
plt.ylabel("Batting Average")
plt.grid(True)
plt.tight_layout()
plt.show()
